# %%
from files.utils.constants import *
from files.utils.utility_functions import *
from files.classes.self_organizing_maps import *

# %%
from sklearn.datasets import make_blobs

ds, gt = make_blobs(n_samples=500, centers=10, cluster_std=0.1)
ds = np.vstack((ds, np.random.uniform(-10, 10, size=(400, 2))))
plot(ds)

# %%
som = SelfOrganizingMaps(data=ds, init_type=PCA, n_cols=7, n_rows=7, sigma=2)
som.fit(data=ds, epochs=1000)

# %%
som.plot_weights_lattice(data=ds)

# %%
plot(ds, c=som.get_residuals(ds))
